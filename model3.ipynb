# %% [markdown]
# # Read in data

# %%
from datetime import timedelta
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

airports = [
    "KATL",
    "KCLT",
    "KDEN",
    "KDFW",
    "KJFK",
    "KMEM",
    "KMIA",
    "KORD",
    "KPHX",
    "KSEA",
]

# %%
DATA_DIRECTORY = Path("code execution development data/old")

# %% [markdown]
# ## LAMP

# %%
def read_lamp(airport):
    lamp = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_lamp.csv.bz2",
        parse_dates=["timestamp", "forecast_timestamp"],
        dtype={"temperature": "int16", "wind_direction":"int16", "wind_gust":"int16", "cloud_ceiling":"float16", "visibility":"int16"}
    )
    return lamp

# %% [markdown]
# ## Config

# %%
def read_config(airport):
    config = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_config.csv.bz2",
        parse_dates=["timestamp", "start_time"]
    )
    config.departure_runways = config.departure_runways.astype(str)
    return config

# %% [markdown]
# ## Runways

# %%
def read_runways(airport):
    runways = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_runways.csv.bz2",
        parse_dates=["timestamp", "departure_runway_actual_time"]
    )
    return runways

# %% [markdown]
# ## TFM

# %%
def read_tfm(airport):
    tfm = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_tfm.csv.bz2",
        parse_dates=["timestamp", "arrival_runway_estimated_time"]
    )
    return tfm

# %% [markdown]
# ## TBFM

# %%
def read_tbfm(airport):
    tbfm = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_tbfm.csv.bz2",
        parse_dates=["timestamp", "scheduled_runway_estimated_time"]
    )
    return tbfm

# %% [markdown]
# ## ETD

# %%
def read_etd(airport):
    etd = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_etd.csv.bz2",
        parse_dates=["departure_runway_estimated_time", "timestamp"]
    )
    return etd

# %% [markdown]
# ## MFS

# %%
def read_mfs(airport):
    etd = pd.read_csv(
        DATA_DIRECTORY / airport / f"{airport}_mfs.csv.bz2"
    )
    return etd

# %% [markdown]
# # Initial Model, Linear Regression

# %%
submission_format = pd.read_csv(
    "code execution development data/test_labels.csv", parse_dates=["timestamp"]
)

# %% [markdown]
# ## Insert Data

# %%
def filter_lamp(current_time):
    # weather data
    valid_lamp = lamp.loc[(lamp.timestamp <= current_time) 
                    & (lamp.timestamp > valid_time) 
                    & (lamp.forecast_timestamp <= current_time) 
                    & (lamp.forecast_timestamp > valid_time)]
    return valid_lamp.iloc[-1]

def filter_config(current_time):
    # runway config data
    valid_config = config.loc[(config.timestamp <= current_time) 
                    & (config.timestamp > valid_time) 
                    & (config.start_time <= current_time) 
                    & (config.start_time > valid_time)]
    try:
        items = valid_config.iloc[-1].departure_runways.split()
        return len(items)
    except:
        return 2

def filter_runways(current_time):
    # traffic (schedule) data
    valid_runways = runways.loc[(runways.timestamp <= current_time) 
                & (runways.timestamp > valid_time) 
                & (runways.departure_runway_actual_time <= current_time) 
                & (runways.departure_runway_actual_time > crunch_time)]
    runway_traffic = valid_runways['gufi'].nunique()
    return runway_traffic

def filter_tbfm(current_time):
    # traffic (schedule) data
    valid_tbfm = tbfm.loc[(tbfm.timestamp <= current_time) 
                    & (tbfm.timestamp > valid_time)]
    return valid_tbfm['gufi'].nunique()

def filter_tfm(current_time):
    # traffic (estimate) data
    valid_tfm = tfm.loc[(tfm.timestamp <= current_time) 
                    & (tfm.timestamp > valid_time)]
    return valid_tfm['gufi'].nunique()
    
def filter_etd(current_time):    
    #etd data
    valid_etd = etd.loc[(etd.timestamp <= current_time) 
                    & (etd.timestamp > valid_time) 
                    & (etd.gufi == df.loc[i].gufi)]
    try:
        return (valid_etd.iloc[-1].departure_runway_estimated_time - current_time).total_seconds()
    except:
        return 3600

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
full_frame = pd.DataFrame()
for a in airports:
    airport = a
    df = submission_format[submission_format.airport == a]
    times = df.timestamp.unique()

    etd = read_etd(airport)
    config = read_config(airport)
    runways = read_runways(airport)
    tbfm = read_tbfm(airport)
    tfm = read_tfm(airport)
    lamp = read_lamp(airport)

    for t in times:
        indices = df[df.timestamp == t].index
        current_time = pd.to_datetime(t)
        valid_time = current_time - pd.Timedelta(30, unit='hours')
        crunch_time = current_time - pd.Timedelta(1, unit='hours')
        
        # insert etd data
        for i in indices:
            df.loc[i, 'etd'] = filter_etd(current_time)
            
        # insert traffic data
        df.loc[indices, 'config'] = filter_config(current_time)
        df.loc[indices, 'runways'] = filter_runways(current_time)
        df.loc[indices, 'traffic_tbfm'] = filter_tbfm(current_time)
        df.loc[indices, 'traffic_tfm'] = filter_tfm(current_time)

        # insert weather data
        current_forecast = filter_lamp(current_time)
        df.loc[indices, 'precip'] = current_forecast.precip
        df.loc[indices, 'lightning_prob'] = current_forecast.lightning_prob
        df.loc[indices, 'cloud'] = filter_lamp(current_time).cloud
        df.loc[indices, 'visibility'] = current_forecast.visibility
        df.loc[indices, 'cloud_ceiling'] = current_forecast.cloud_ceiling
        df.loc[indices, 'wind_gust'] = current_forecast.wind_gust
        df.loc[indices, 'wind_speed'] = current_forecast.wind_speed
        df.loc[indices, 'wind_direction'] = current_forecast.wind_direction
        df.loc[indices, 'temperature'] = current_forecast.temperature
        
    full_frame = pd.concat([full_frame, df])
        
# insert metadata
metadata = pd.concat([read_mfs('KATL'),
                      read_mfs('KCLT'),
                      read_mfs('KDEN'),
                      read_mfs('KDFW'),
                      read_mfs('KJFK'),
                      read_mfs('KMEM'),
                      read_mfs('KMIA'),
                      read_mfs('KORD'),
                      read_mfs('KPHX'),
                      read_mfs('KSEA')])

full_frame = full_frame.merge(metadata, how='left', on='gufi')

full_frame.head(5)
# Out:
#                                    gufi           timestamp airport  \
# 0  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 11:15:00    KATL
# 1  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 11:15:00    KATL
# 2  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 12:00:00    KATL
# 3  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 12:00:00    KATL
# 4   AAL153.ATL.CLT.201114.1137.0016.TFM 2020-11-15 10:30:00    KATL
#
#    minutes_until_pushback     etd  config  runways  traffic_tbfm  traffic_tfm  \
# 0                      86  6300.0     2.0      1.0         833.0       1710.0
# 1                      86  6300.0     2.0      1.0         833.0       1710.0
# 2                      41  3600.0     2.0      4.0         877.0       1752.0
# 3                      41  3600.0     2.0      4.0         877.0       1752.0
# 4                      62  4980.0     2.0      0.0         808.0       1677.0
#
#   precip  ... cloud_ceiling wind_gust  wind_speed  wind_direction  \
# 0  False  ...           8.0       0.0         2.0            13.0
# 1  False  ...           8.0       0.0         2.0            13.0
# 2  False  ...           8.0       0.0         5.0            14.0
# 3  False  ...           8.0       0.0         5.0            14.0
# 4  False  ...           8.0       0.0         5.0            11.0
#
#    temperature  aircraft_engine_class  aircraft_type  major_carrier  \
# 0         54.0                    JET           A319            AAL
# 1         54.0                    JET           A319            AAL
# 2         53.0                    JET           A319            AAL
# 3         53.0                    JET           A319            AAL
# 4         53.0                    JET           A320            AAL
#
#                flight_type isdeparture
# 0  SCHEDULED_AIR_TRANSPORT        True
# 1  SCHEDULED_AIR_TRANSPORT       False
# 2  SCHEDULED_AIR_TRANSPORT        True
# 3  SCHEDULED_AIR_TRANSPORT       False
# 4  SCHEDULED_AIR_TRANSPORT        True
#
# [5 rows x 23 columns]

# %% [markdown]
# # Data Prep

# %% [markdown]
# ## Distribution

# %%
full_frame.select_dtypes(include='number').describe()
# Out:
#        minutes_until_pushback           etd       config      runways  \
# count             2356.000000   2356.000000  2356.000000  2356.000000
# mean                44.109932   3453.388795     1.972411    28.724958
# std                 28.722366   1638.195583     0.578895    23.640350
# min                  1.000000 -10920.000000     1.000000     0.000000
# 25%                 21.000000   2280.000000     2.000000    10.000000
# 50%                 43.000000   3540.000000     2.000000    22.000000
# 75%                 63.000000   4740.000000     2.000000    44.000000
# max                271.000000   9840.000000     4.000000    85.000000
#
#        traffic_tbfm  traffic_tfm   visibility  cloud_ceiling    wind_gust  \
# count   2356.000000  2356.000000  2356.000000    2356.000000  2356.000000
# mean     854.047114  1477.465620     6.750849       7.180390     6.518251
# std      286.623268   477.352844     0.773979       1.421451    11.394941
# min      229.000000   389.000000     1.000000       2.000000     0.000000
# 25%      626.000000  1053.000000     7.000000       7.000000     0.000000
# 50%      882.000000  1607.000000     7.000000       8.000000     0.000000
# 75%     1155.000000  1959.000000     7.000000       8.000000    19.000000
# max     1253.000000  2108.000000     7.000000       8.000000    31.000000
#
#         wind_speed  wind_direction  temperature
# count  2356.000000     2356.000000  2356.000000
# mean     10.754669       18.072581    56.983871
# std       6.077706        7.727816    15.545719
# min       1.000000        1.000000    22.000000
# 25%       5.000000       12.000000    46.000000
# 50%       9.000000       16.000000    58.000000
# 75%      16.000000       24.000000    75.000000
# max      23.000000       35.000000    80.000000

# %%
full_frame.select_dtypes(exclude='number').describe()
# Out:
#                                         gufi            timestamp airport  \
# count                                   2356                 2356    2356
# unique                                  1228                   17      10
# top     DAL8903.MIA.ATL.201114.0057.0044.TFM  2020-11-15 00:00:00    KATL
# freq                                       8                  485     416
# first                                    NaN  2020-11-15 00:00:00     NaN
# last                                     NaN  2020-11-15 12:00:00     NaN
#
#        precip lightning_prob cloud aircraft_engine_class aircraft_type  \
# count    2356           2356  2356                  2356          2356
# unique      2              3     5                     2            37
# top     False              N    FW                   JET          A321
# freq     1991           2338   681                  2320           322
# first     NaN            NaN   NaN                   NaN           NaN
# last      NaN            NaN   NaN                   NaN           NaN
#
#        major_carrier              flight_type isdeparture
# count           1902                     2182        2356
# unique             3                        2           2
# top              AAL  SCHEDULED_AIR_TRANSPORT        True
# freq             958                     2170        2046
# first            NaN                      NaN         NaN
# last             NaN                      NaN         NaN

# %% [markdown]
# ## Missing Values

# %%
full_frame.isnull().sum()
# Out:
# gufi                        0
# timestamp                   0
# airport                     0
# minutes_until_pushback      0
# etd                         0
# config                      0
# runways                     0
# traffic_tbfm                0
# traffic_tfm                 0
# precip                      0
# lightning_prob              0
# cloud                       0
# visibility                  0
# cloud_ceiling               0
# wind_gust                   0
# wind_speed                  0
# wind_direction              0
# temperature                 0
# aircraft_engine_class       0
# aircraft_type               0
# major_carrier             454
# flight_type               174
# isdeparture                 0
# dtype: int64

# %%
# impute missing values with mode
full_frame.major_carrier.fillna(full_frame.major_carrier.mode()[0], inplace=True)
full_frame.flight_type.fillna(full_frame.flight_type.mode()[0], inplace=True)

# %% [markdown]
# ## Outliers

# %%
from scipy import stats
z_scores = stats.zscore(full_frame.select_dtypes(include='number').describe())
z_scores
# Out:
#        minutes_until_pushback       etd    config   runways  traffic_tbfm  \
# count                2.631246  0.043772  2.645749  2.644459      2.218603
# mean                -0.406501  0.243871 -0.377917 -0.380062     -0.160222
# std                 -0.426719 -0.087114 -0.379707 -0.386670     -1.058920
# min                 -0.463146 -2.376999 -0.379166 -0.417393     -1.150185
# 25%                 -0.436866  0.029914 -0.377882 -0.404397     -0.521408
# 50%                 -0.407959  0.259664 -0.377882 -0.388801     -0.115950
# 75%                 -0.381680  0.478474 -0.377882 -0.360210      0.316434
# max                 -0.108375  1.408418 -0.375313 -0.306927      0.471648
#
#        traffic_tfm  visibility  cloud_ceiling  wind_gust  wind_speed  \
# count     1.352411    2.645737       2.645737   2.645522    2.645661
# mean      0.071602   -0.375991      -0.376371  -0.382034   -0.377132
# std      -1.386455   -0.383678      -0.383780  -0.375750   -0.383160
# min      -1.515264   -0.383388      -0.383036  -0.390434   -0.389705
# 25%      -0.547223   -0.375670      -0.376603  -0.390434   -0.384549
# 50%       0.260449   -0.375670      -0.375316  -0.390434   -0.379394
# 75%       0.773627   -0.375670      -0.375316  -0.365950   -0.370371
# max       0.990853   -0.375670      -0.375316  -0.350487   -0.361349
#
#        wind_direction  temperature
# count        2.645547     2.644721
# mean        -0.375589    -0.369322
# std         -0.388957    -0.423648
# min         -0.397651    -0.415187
# 25%         -0.383437    -0.383722
# 50%         -0.378268    -0.367990
# 75%         -0.367930    -0.345703
# max         -0.353715    -0.339148

# %%
z_scores[z_scores.abs() >= 3].count()
# Out:
# minutes_until_pushback    0
# etd                       0
# config                    0
# runways                   0
# traffic_tbfm              0
# traffic_tfm               0
# visibility                0
# cloud_ceiling             0
# wind_gust                 0
# wind_speed                0
# wind_direction            0
# temperature               0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
full_frame.nunique()
# Out:
# gufi                      1228
# timestamp                   17
# airport                     10
# minutes_until_pushback     133
# etd                        142
# config                       4
# runways                     46
# traffic_tbfm               114
# traffic_tfm                118
# precip                       2
# lightning_prob               3
# cloud                        5
# visibility                   4
# cloud_ceiling                6
# wind_gust                   13
# wind_speed                  23
# wind_direction              29
# temperature                 39
# aircraft_engine_class        2
# aircraft_type               37
# major_carrier                3
# flight_type                  2
# isdeparture                  2
# dtype: int64

# %%
# binary encoding
full_frame.replace(False, 0, inplace=True)
full_frame.replace(True, 0, inplace=True)

# %%
# nominal encoding
full_frame = pd.get_dummies(full_frame, columns=['airport',
                                 'cloud', 
                                 'lightning_prob',
                                 'aircraft_engine_class',
                                 'aircraft_type',
                                 'major_carrier',
                                 'flight_type'], 
                    drop_first=True)
full_frame.head(5)
# Out:
#                                    gufi           timestamp  \
# 0  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 11:15:00
# 1  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 11:15:00
# 2  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 12:00:00
# 3  AAL1227.ATL.MIA.201114.1242.0052.TFM 2020-11-15 12:00:00
# 4   AAL153.ATL.CLT.201114.1137.0016.TFM 2020-11-15 10:30:00
#
#    minutes_until_pushback     etd  config  runways  traffic_tbfm  traffic_tfm  \
# 0                      86  6300.0     2.0      1.0         833.0       1710.0
# 1                      86  6300.0     2.0      1.0         833.0       1710.0
# 2                      41  3600.0     2.0      4.0         877.0       1752.0
# 3                      41  3600.0     2.0      4.0         877.0       1752.0
# 4                      62  4980.0     2.0      0.0         808.0       1677.0
#
#    precip  visibility  ...  aircraft_type_E170  aircraft_type_E55P  \
# 0       0         7.0  ...                   0                   0
# 1       0         7.0  ...                   0                   0
# 2       0         7.0  ...                   0                   0
# 3       0         7.0  ...                   0                   0
# 4       0         7.0  ...                   0                   0
#
#    aircraft_type_E75L  aircraft_type_E75S  aircraft_type_F900  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    aircraft_type_MD11  aircraft_type_PC12  major_carrier_DAL  \
# 0                   0                   0                  0
# 1                   0                   0                  0
# 2                   0                   0                  0
# 3                   0                   0                  0
# 4                   0                   0                  0
#
#    major_carrier_UAL  flight_type_SCHEDULED_AIR_TRANSPORT
# 0                  0                                    1
# 1                  0                                    1
# 2                  0                                    1
# 3                  0                                    1
# 4                  0                                    1
#
# [5 rows x 71 columns]

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Model 1: All Features

# %%
import statsmodels.api as sm

Y = full_frame['minutes_until_pushback']
X = full_frame.drop(columns=['gufi', 'timestamp', 'minutes_until_pushback'])
X = sm.add_constant(X)

model = sm.OLS(Y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     minutes_until_pushback   R-squared:                       0.586
# Model:                                OLS   Adj. R-squared:                  0.574
# Method:                     Least Squares   F-statistic:                     49.85
# Date:                    Sun, 02 Apr 2023   Prob (F-statistic):               0.00
# Time:                            11:27:46   Log-Likelihood:                -10215.
# No. Observations:                    2356   AIC:                         2.056e+04
# Df Residuals:                        2290   BIC:                         2.094e+04
# Df Model:                              65
# Covariance Type:                nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  19.6966     54.536      0.361      0.718     -87.248     126.641
# etd                                     0.0129      0.000     51.517      0.000       0.012       0.013
# config                                  7.2457      3.174      2.283      0.023       1.022      13.470
# runways                                 0.1243      0.027      4.560      0.000       0.071       0.178
# traffic_tbfm                           -0.0228      0.064     -0.357      0.721      -0.148       0.103
# traffic_tfm                             0.0088      0.068      0.129      0.897      -0.125       0.143
# precip                               5.171e-13   4.91e-12      0.105      0.916   -9.11e-12    1.01e-11
# visibility                              2.9908      0.884      3.384      0.001       1.258       4.724
# cloud_ceiling                          -7.4223      1.336     -5.556      0.000     -10.042      -4.802
# wind_gust                              -0.1350      0.184     -0.733      0.464      -0.496       0.226
# wind_speed                              0.1165      0.350      0.333      0.740      -0.570       0.803
# wind_direction                         -0.1955      0.134     -1.458      0.145      -0.459       0.068
# temperature                             0.3471      0.200      1.736      0.083      -0.045       0.739
# isdeparture                         -1.372e-13    4.6e-13     -0.299      0.765   -1.04e-12    7.64e-13
# airport_KCLT                           -7.7230     19.913     -0.388      0.698     -46.772      31.326
# airport_KDEN                           11.6336     14.450      0.805      0.421     -16.703      39.970
# airport_KDFW                           -6.0603      5.496     -1.103      0.270     -16.838       4.717
# airport_KJFK                            7.5031     44.193      0.170      0.865     -79.159      94.165
# airport_KMEM                            3.1417     50.929      0.062      0.951     -96.730     103.014
# airport_KMIA                          -13.8834     38.491     -0.361      0.718     -89.364      61.597
# airport_KORD                           -4.7535     10.578     -0.449      0.653     -25.497      15.990
# airport_KPHX                           -8.7715     34.321     -0.256      0.798     -76.076      58.533
# airport_KSEA                           20.4283     29.974      0.682      0.496     -38.351      79.207
# cloud_CL                                5.7529      3.557      1.618      0.106      -1.221      12.727
# cloud_FW                                4.9073      1.360      3.608      0.000       2.240       7.575
# cloud_OV                              -19.6153      4.906     -3.998      0.000     -29.235      -9.995
# cloud_SC                                4.7846      1.655      2.891      0.004       1.539       8.030
# lightning_prob_M                       33.1502     11.067      2.995      0.003      11.448      54.852
# lightning_prob_N                       -4.0076      6.278     -0.638      0.523     -16.319       8.304
# aircraft_engine_class_TURBO            -0.6769      5.694     -0.119      0.905     -11.843      10.489
# aircraft_type_A21N                      1.4392     11.716      0.123      0.902     -21.537      24.415
# aircraft_type_A306                      6.1837      7.888      0.784      0.433      -9.285      21.652
# aircraft_type_A319                      1.2926      4.432      0.292      0.771      -7.399       9.984
# aircraft_type_A320                     -1.8818      4.459     -0.422      0.673     -10.625       6.861
# aircraft_type_A321                      1.0072      4.245      0.237      0.812      -7.318       9.332
# aircraft_type_A333                    -16.4201     10.346     -1.587      0.113     -36.708       3.868
# aircraft_type_B712                      2.6704      4.853      0.550      0.582      -6.846      12.187
# aircraft_type_B737                      7.4407      4.884      1.523      0.128      -2.137      17.019
# aircraft_type_B738                     -1.2983      4.263     -0.305      0.761      -9.658       7.061
# aircraft_type_B739                     -1.0133      4.367     -0.232      0.817      -9.577       7.551
# aircraft_type_B752                      8.4828      4.748      1.787      0.074      -0.828      17.793
# aircraft_type_B753                     -0.5102      6.161     -0.083      0.934     -12.592      11.572
# aircraft_type_B763                      8.8851      4.943      1.798      0.072      -0.808      18.578
# aircraft_type_B764                     14.4869      6.524      2.221      0.026       1.694      27.280
# aircraft_type_B772                     -3.3954      5.489     -0.619      0.536     -14.159       7.369
# aircraft_type_B77L                     -8.2392      8.089     -1.019      0.309     -24.101       7.623
# aircraft_type_B77W                    -12.6774      8.252     -1.536      0.125     -28.860       3.506
# aircraft_type_B788                     -8.3594      9.436     -0.886      0.376     -26.863      10.144
# aircraft_type_B789                      3.3915      6.466      0.524      0.600      -9.289      16.072
# aircraft_type_BCS1                     -3.4423     10.375     -0.332      0.740     -23.787      16.903
# aircraft_type_C25A                    -16.6655     18.522     -0.900      0.368     -52.986      19.655
# aircraft_type_C56X                      5.7628     15.044      0.383      0.702     -23.738      35.264
# aircraft_type_CRJ2                     -2.5581      4.563     -0.561      0.575     -11.505       6.389
# aircraft_type_CRJ7                     -2.6579      4.489     -0.592      0.554     -11.460       6.145
# aircraft_type_CRJ9                     -3.2985      4.426     -0.745      0.456     -11.979       5.382
# aircraft_type_DC10                     -5.3187      7.525     -0.707      0.480     -20.076       9.438
# aircraft_type_DH8D                      0.3322      6.339      0.052      0.958     -12.098      12.762
# aircraft_type_E135                      1.3161      6.292      0.209      0.834     -11.022      13.654
# aircraft_type_E145                     -7.5009      4.840     -1.550      0.121     -16.992       1.991
# aircraft_type_E170                     -8.2297      4.737     -1.737      0.082     -17.519       1.060
# aircraft_type_E55P                     54.5402     18.920      2.883      0.004      17.438      91.642
# aircraft_type_E75L                     -8.4912      4.527     -1.876      0.061     -17.369       0.387
# aircraft_type_E75S                     -5.4981      5.105     -1.077      0.282     -15.510       4.514
# aircraft_type_F900                     -3.1282     15.758     -0.199      0.843     -34.030      27.774
# aircraft_type_MD11                     20.4696      5.768      3.549      0.000       9.159      31.780
# aircraft_type_PC12                    -11.6222     13.410     -0.867      0.386     -37.919      14.675
# major_carrier_DAL                       1.7950      1.483      1.210      0.226      -1.114       4.704
# major_carrier_UAL                      -0.6083      1.841     -0.330      0.741      -4.219       3.002
# flight_type_SCHEDULED_AIR_TRANSPORT    -9.1905     11.350     -0.810      0.418     -31.447      13.066
# ==============================================================================
# Omnibus:                     2136.252   Durbin-Watson:                   0.895
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            96984.860
# Skew:                           4.187   Prob(JB):                         0.00
# Kurtosis:                      33.296   Cond. No.                     1.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.49e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# calculate MAE
from sklearn.metrics import mean_absolute_error as mae
ypred = model.predict()
MAE = mae(Y, ypred)
MAE
# Out:
# 10.27396558092066

# %%
# check for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

# create VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
vif_data
# Out:
#                                 feature          VIF
# 0                                 const     0.000000
# 1                                   etd     1.135065
# 2                                config    22.629130
# 3                               runways     2.784137
# 4                          traffic_tbfm  2252.609645
# ..                                  ...          ...
# 64                   aircraft_type_MD11     2.896605
# 65                   aircraft_type_PC12          inf
# 66                    major_carrier_DAL     2.741051
# 67                    major_carrier_UAL     2.963232
# 68  flight_type_SCHEDULED_AIR_TRANSPORT          inf
#
# [69 rows x 2 columns]

# %% [markdown]
# ## Model 2: Reduced Features

# %%
# reduce features
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SequentialFeatureSelector

# re-define independent variables
X = full_frame.drop(columns=['gufi', 'timestamp', 'minutes_until_pushback'])

# linear regression estimator to be used in feature selection
reg = LinearRegression().fit(X, Y)

# %%
# reduce features using SequentialFeatureSelector
sfs = SequentialFeatureSelector(reg, n_features_to_select=8)
sfs.fit(X, Y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), n_features_to_select=8)

# %%
# return selected features
sfs.get_feature_names_out()
# Out:
# array(['etd', 'wind_direction', 'airport_KCLT', 'airport_KORD',
#        'aircraft_type_B752', 'aircraft_type_B763', 'aircraft_type_E145',
#        'aircraft_type_E170'], dtype=object)

# %%
# re-fit model
X = full_frame[['etd', 'wind_direction', 'airport_KCLT', 'airport_KORD',
       'aircraft_type_B752', 'aircraft_type_B763', 'aircraft_type_E145',
       'aircraft_type_E170']]
X = sm.add_constant(X)

model2 = sm.OLS(Y,X).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     minutes_until_pushback   R-squared:                       0.539
# Model:                                OLS   Adj. R-squared:                  0.537
# Method:                     Least Squares   F-statistic:                     342.7
# Date:                    Sun, 02 Apr 2023   Prob (F-statistic):               0.00
# Time:                            11:27:53   Log-Likelihood:                -10342.
# No. Observations:                    2356   AIC:                         2.070e+04
# Df Residuals:                        2347   BIC:                         2.075e+04
# Df Model:                               8
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  4.2990      1.383      3.109      0.002       1.587       7.011
# etd                    0.0128      0.000     51.673      0.000       0.012       0.013
# wind_direction        -0.1569      0.054     -2.926      0.003      -0.262      -0.052
# airport_KCLT          -7.3886      1.492     -4.953      0.000     -10.314      -4.464
# airport_KORD          -9.4155      1.445     -6.514      0.000     -12.250      -6.581
# aircraft_type_B752    10.1641      2.351      4.323      0.000       5.554      14.774
# aircraft_type_B763     9.3781      2.778      3.376      0.001       3.931      14.825
# aircraft_type_E145    -7.2123      2.561     -2.816      0.005     -12.234      -2.190
# aircraft_type_E170    -7.8682      2.133     -3.690      0.000     -12.050      -3.686
# ==============================================================================
# Omnibus:                     2288.850   Durbin-Watson:                   0.864
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           127089.597
# Skew:                           4.612   Prob(JB):                         0.00
# Kurtosis:                      37.778   Cond. No.                     2.66e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# re-calculate MAE
from sklearn.metrics import mean_absolute_error as mae
ypred = model.predict()
MAE = mae(Y, ypred)
MAE
# Out:
# 10.27396558092066

# %%
# re-check for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

# create VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
vif_data
# Out:
#               feature        VIF
# 0               const  11.800006
# 1                 etd   1.008809
# 2      wind_direction   1.059428
# 3        airport_KCLT   1.056780
# 4        airport_KORD   1.028708
# 5  aircraft_type_B752   1.023950
# 6  aircraft_type_B763   1.008269
# 7  aircraft_type_E145   1.020636
# 8  aircraft_type_E170   1.009005

# %% [markdown]
# ## Model 3: PCR

# %%
# perform PCA
import numpy as np
from sklearn.preprocessing import StandardScaler 
from sklearn.decomposition import PCA

data = full_frame.drop(columns=['gufi', 'timestamp', 'minutes_until_pushback'])
scale = StandardScaler()
X = scale.fit_transform(data)


X
# Out:
# array([[ 1.73801929,  0.04766837, -1.17303015, ..., -0.57212232,
#         -0.42677568,  0.07155036],
#        [ 1.73801929,  0.04766837, -1.17303015, ..., -0.57212232,
#         -0.42677568,  0.07155036],
#        [ 0.08951454,  0.04766837, -1.04610154, ..., -0.57212232,
#         -0.42677568,  0.07155036],
#        ...,
#        [-0.4233536 , -1.68012681, -0.1152917 , ..., -0.57212232,
#          2.34315132,  0.07155036],
#        [ 1.1885177 , -1.68012681, -1.17303015, ..., -0.57212232,
#          2.34315132,  0.07155036],
#        [ 1.1885177 , -1.68012681, -1.17303015, ..., -0.57212232,
#          2.34315132,  0.07155036]])

# %%
pca=PCA()
X_red = pca.fit_transform(X)

# %%
np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 4)*100)[0:10]
# Out:
# array([ 7.6 , 14.38, 19.45, 23.72, 27.09, 30.26, 33.05, 35.8 , 38.26,
#        40.44])

# %%
X = sm.add_constant(X)
model = sm.OLS(Y,X[:,0:10]).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     minutes_until_pushback   R-squared:                       0.525
# Model:                                OLS   Adj. R-squared:                  0.523
# Method:                     Least Squares   F-statistic:                     324.1
# Date:                    Sun, 02 Apr 2023   Prob (F-statistic):               0.00
# Time:                            11:41:20   Log-Likelihood:                -10377.
# No. Observations:                    2356   AIC:                         2.077e+04
# Df Residuals:                        2347   BIC:                         2.082e+04
# Df Model:                               8
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.1099      0.409    107.959      0.000      43.309      44.911
# x1            20.3426      0.419     48.581      0.000      19.522      21.164
# x2             1.8093      0.450      4.016      0.000       0.926       2.693
# x3             1.7165      0.580      2.958      0.003       0.579       2.854
# x4            -2.9135      2.475     -1.177      0.239      -7.768       1.941
# x5             0.4817      2.315      0.208      0.835      -4.058       5.021
# x6          4.028e-15   1.48e-16     27.152      0.000    3.74e-15    4.32e-15
# x7             1.9496      0.615      3.171      0.002       0.744       3.155
# x8            -1.2588      0.705     -1.786      0.074      -2.641       0.123
# x9            -1.2725      0.477     -2.670      0.008      -2.207      -0.338
# ==============================================================================
# Omnibus:                     2149.921   Durbin-Watson:                   0.854
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94505.158
# Skew:                           4.246   Prob(JB):                         0.00
# Kurtosis:                      32.842   Cond. No.                     2.63e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.01e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# re-calculate MAE
from sklearn.metrics import mean_absolute_error as mae
ypred = model.predict()
MAE = mae(Y, ypred)
MAE
# Out:
# 11.289810632306754
